# %%
import numpy as np
import torch
from PIL import Image
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F

# %%
img = Image.open('./dataset/images/10001.png')
img = F.pil_to_tensor(img).squeeze()

# %%
plt.imshow(img)

# %%
plt.imshow(torch.tensor(img)[100:200, 100:200])
# Out:
# /var/folders/9j/6klzzkl955n61jys96cml3fr0000gn/T/ipykernel_13801/3007845322.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.imshow(torch.tensor(img)[100:200, 100:200])

# %%
import torch

def extract_patch(image, x, y, patch_width, patch_height):
    image_width, image_height = image.shape[-2:]
    
    x = min(image_width, max(0, x))
    y = min(image_height, max(0, y))
    
    x_offset = patch_width // 2
    y_offset = patch_height // 2
    
    x_min = max(0, x - x_offset)
    x_max = min(image_width, x + x_offset)
    y_min = max(0, y - y_offset)
    y_max = min(image_height, y + y_offset)
    
    x_offset = max(0, x_offset - x)
    y_offset = max(0, y_offset - y)
    
    patch = torch.zeros(patch_width, patch_height)
    
    patch[
        x_offset:x_offset + x_max - x_min,
        y_offset:y_offset + y_max - y_min,
    ] = image[
        ...,
        x_min:x_max,
        y_min:y_max,
    ]
    
    return patch

# Example usage:
width, height = img.shape[-2:]
patch = extract_patch(img, -2000, -2000, 1000, 1000)
print(patch.shape)
print(img.shape)

plt.imshow(patch)
# Out:
# torch.Size([1000, 1000])
# torch.Size([1840, 1360])
